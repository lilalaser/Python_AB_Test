# %% [markdown]
# # AB Test: Online Advertising Effectiveness Study

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Online advertising is a central driver of customer engagement and revenue, but its effectiveness depends on both whether ads are shown and how they are delivered. Factors such as exposure frequency and timing can influence user behavior and may determine whether advertising campaigns are successful or not.
#
# This project analyzes the effectiveness of online advertisements in increasing customer purchases on a company's website. The analysis is based on a dataset obtained from an A/B testing experiment, where 20,000 customers were subjected to either an advertisement (ad) or a public service announcement (psa).
#
# This project looks at whether online ads actually help a company sell more products on their website. The company ran an experiment where they showed 20,000 customers either an advertisement or a public service announcement (PSA) for 31 days to see which one worked better.
#
# The analysis breaks down into four main parts:
#
#    -  Comparing ad and PSA results: Are customers who saw ads more likely to buy than those who saw PSAs.
#
#    -  Looking at exposure frequency: Does seeing the same ad multiple times increase purchases or does it start to have less effect.
#
#    -  Checking time-of-day patterns: Do ads work better at certain times of the day when more customers are actively browsing.
#
#    -  Comparing how the two groups respond: Finally, we see if ads and PSAs have different effects as exposure increases.
#
# The main goal is to show a clear, data-driven way to understand A/B test results and find practical insights about how ad exposure influences customer behaviour.

# %% [markdown]
# ## Table of Contents
# 1. [Introduction](#introduction)
# 2. [Data Source](#data-source)
# 3. [Data Preparation](#data-preparation)
# 4. [Data Analysis](#data-analysis)
#     - [4.1 Analysis of Ad Exposure at Group Level (Ad vs. PSA)](#41-analysis-of-ad-exposure-at-group-level-ad-vs-psa)
#     - [4.2 Analysis of Ad Exposure at Individual Ad Level](#42-analysis-of-ad-exposure-at-individual-ad-level)
#     - [4.3 Ad Exposure at Peak Ad Hours Level](#43-ad-exposure-at-peak-ad-hours-level)
#     - [4.4 Purchase Rates by Exposure Level: Ads vs. PSA](#44-purchase-rates-by-exposure-level-ads-vs-psa)
# 5. [Conclusion and Outlook](#conclusion-and-outlook)

# %% [markdown]
# ## 2. Data Source

# %% [markdown]
# The dataset used for this analysis is available on Kaggle:
#
# <https://www.kaggle.com/datasets/farhadzeynalli/online-advertising-effectiveness-study-ab-testing?resource=download>
#
#
# Columns:
# - customerID: unique identifier for the customer
# - test group: composed of 60% 'ad' and 40% 'psa' group.
# - made_purchase: A Boolean value representing whether or not the user made a purchase after seeing an advertisement.
# - days_with_most_add: A day of the month when the user saw the most ads.
# - peak ad hours: An hour of the day when the user saw the most ads.
# - ad_count: total number of ads seen by each user.

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# This section loads the A/B test dataset and performs initial cleaning to prepare it for analysis. The necessary libraries for data manipulation, statistical testing, and visualization are imported, then the dataset is loaded and inspected for structure and completeness. Column names are cleaned by removing extra spaces and fixing naming inconsistencies to make the data easier to work with throughout the analysis.

# %%
# Import required libraries
import pandas as pd
import numpy as np
from statsmodels.stats.proportion import proportions_ztest
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import statsmodels.formula.api as smf

# %%
# Import and preview online ad dataset
ab_test_df = pd.read_csv('Path/to/Data_AB_Test.csv')
ab_test_df.head(10)
ab_test_df.columns
# Out:
# Index(['customerID', 'test group', 'made_purchase', 'days_with_most_add',
#        'peak ad hours', 'ad_count'],
#       dtype='object')

# %%
# Check for missing values
ab_test_df.isnull().sum()
# Out:
# customerID            0
# test group            0
# made_purchase         0
# days_with_most_add    0
# peak ad hours         0
# ad_count              0
# dtype: int64

# %% [markdown]
# There are no missing values.

# %%
# Replace spaces in data with underscores for improved clarity
ab_test_df.rename(columns=lambda x: x.strip().replace(" ", "_"), inplace=True)

# Rename column 'days_with_most_add' to 'days_with_most_ads'
ab_test_df.rename(columns={'days_with_most_add': 'days_with_most_ads'}, inplace=True)
ab_test_df.head()
# Out:
#    customerID test_group  made_purchase  days_with_most_ads  peak_ad_hours  \
# 0           1         ad          False                  24             20
# 1           2        psa          False                  21             16
# 2           3        psa          False                   1             18
# 3           4         ad          False                  20             23
# 4           5         ad          False                   3             13
#
#    ad_count
# 0         5
# 1         9
# 2         8
# 3         7
# 4         5

# %% [markdown]
# ## 4. Data Analysis

# %% [markdown]
# This section examines the A/B test data to identify patterns in how ad exposure affects purchase behavior. The analysis progresses from broad comparisons between the two test groups, to individual-level exposure effects, to time-of-day patterns, and finally to direct comparisons of how ads and PSAs influence purchases differently as exposure increases. Each subsection combines descriptive statistics with statistical tests to distinguish genuine patterns from random variation.

# %%
# Show all columns
pd.set_option('display.max_columns', None)

# %%
ab_test_df.groupby('test_group')[['days_with_most_ads','peak_ad_hours','ad_count']].describe()
# Out:
#            days_with_most_ads                                             \
#                         count       mean       std  min  25%   50%   75%
# test_group
# ad                    12053.0  15.593960  8.635782  1.0  8.0  16.0  23.0
# psa                    7947.0  15.448849  8.690007  1.0  8.0  16.0  23.0
#
#                  peak_ad_hours                                              \
#              max         count       mean       std  min   25%   50%   75%
# test_group
# ad          30.0       12053.0  15.821870  6.229011  0.0  13.0  17.0  20.0
# psa         30.0        7947.0  15.964263  6.187886  0.0  15.0  18.0  21.0
#
#                  ad_count
#              max    count      mean       std  min  25%  50%  75%   max
# test_group
# ad          23.0  12053.0  6.381067  2.554334  1.0  5.0  7.0  9.0  10.0
# psa         23.0   7947.0  6.408959  2.534506  1.0  5.0  7.0  9.0  10.0

# %% [markdown]
# The table shows descriptive statistics for three exposure-related variables: days_with_most_ads, peak_ad_hours, and ad_count—grouped by test_group (ad vs. psa).
# The dataset contains more users in the ad group (12,053) than in the PSA group (7,947), which is important to keep in mind when comparing purchase rates. Nonetheless, the descriptive statistics indicate that the three variables are well balanced between psa and ad groups which makes it unlikely that observed differences are due to systematic differences in the data.

# %% [markdown]
# ### 4.1 Analysis of Ad Exposure at Group Level (Ad vs. PSA)

# %% [markdown]
# This subsection compares purchase behavior between users exposed to ads and those exposed to PSAs.

# %%
# Calculate percentage of purchases for each test group

group_purchase_rate_df = ab_test_df.groupby(['test_group']).agg({'made_purchase': 'mean'}) * 100
group_purchase_rate_df.rename(columns={'made_purchase': 'purchase_rate_pct'}, inplace=True)
group_purchase_rate_df
# Out:
#             purchase_rate_pct
# test_group
# ad                   6.662242
# psa                  3.233925

# %% [markdown]
# The ad group has a purchase rate of approximately 6.66%, which is more than double the PSA group's rate of 3.23%.
#
# Based on these percentages, users who saw ads were more likely to make a purchase than users who saw a psa. However, this comparison is only descriptive and a statistical test is necessary to confirm whether this difference is real and not random.

# %%
# Include a z-test to check for statistical significance
# Count purchases per group

ad_purchases = ab_test_df.loc[ab_test_df['test_group'] == 'ad', 'made_purchase'].sum()
psa_purchases = ab_test_df.loc[ab_test_df['test_group'] == 'psa', 'made_purchase'].sum() 

# Count totals
ad_total = (ab_test_df['test_group'] == 'ad').sum()
psa_total = (ab_test_df['test_group'] == 'psa').sum()

# Run z-test
count = np.array([ad_purchases, psa_purchases])
nobs = np.array([ad_total, psa_total])

stat, p_value = proportions_ztest(count, nobs)

print('Z-statistic:', round(stat,2))
print('p-value:', p_value)
# Out:
# Z-statistic: 10.59
# p-value: 3.310501343616513e-26

# %% [markdown]
# To test whether the difference in purchase rates between the Ad group and the PSA group is statistically significant, a two-proportion z-test was performed.
# - Z-statistic: 10.59
# - p-value: 3.31 × 10⁻²⁶
# The result is highly statistically significant (p < 0.0001), indicating that users exposed to ads are significantly more likely to make a purchase compared to users exposed to PSAs.
#
# Although the sample sizes of the two groups differ (12,053 in Ad vs. 7,947 in PSA, this imbalance does not affect the validity of the analysis. Both groups are sufficiently large, and the statistical test used (two-proportion z-test) explicitly accounts for unequal sample sizes. Therefore, the results remain reliable and unbiased.

# %% [markdown]
# All in all, the ad group exhibits a purchase rate of 6.66%, more than double the 3.23% observed in the PSA group. A two-proportion z-test confirms that this difference is highly statistically significant (z = 10.59, p < 0.0001). This provides strong evidence that exposure to advertisements increases the likelihood of making a purchase compared to exposure to PSAs.

# %% [markdown]
# ### 4.2 Analysis of Ad Exposure at Individual Ad Level

# %% [markdown]
# This section analyzes how the number of ads seen by a user (ad_count) relates to purchase behavior.

# %%
# Group by 'ad_count' to see how the number of ads seen affects the likelihood of a purchase in percent
adcount_purchase_rate_df = ab_test_df.groupby('ad_count').agg({'made_purchase': 'mean'}) * 100
adcount_purchase_rate_df

# Rename 'made_purchase' to 'purchase_rate_pct'
adcount_purchase_rate_df.rename(columns = {'made_purchase': 'purchase_rate_pct'}, inplace = True)
adcount_purchase_rate_df
# Out:
#           purchase_rate_pct
# ad_count
# 1                  4.747475
# 2                  6.069652
# 3                  5.615764
# 4                  4.137235
# 5                  4.937190
# 6                  5.173116
# 7                  6.196841
# 8                  5.382545
# 9                  5.091884
# 10                 5.412054

# %%
# Create line plot visualizing adcount_purchase_rate_df

# Create line plot
plt.figure(figsize=(10,6))
sns.lineplot(data=adcount_purchase_rate_df, x='ad_count', y='purchase_rate_pct', marker='o')
plt.title('Purchase Rate by Number of Ads Seen')
plt.xlabel('Number of Ads Seen (ad_count)')
plt.ylabel('Purchase Rate (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows the purchase rate by number of ads seen (ad_count). Increased ad exposure slightly increases the likelihood of a purchase, but only up to a certain point (7 ads). In addition to that, the pattern is not entirely consistent: the likelihood of a purchase rises when test persons are exposed to two ads, but decreases again
# when exposed to more than two ads. This suggests that seeing more ads can make a purchase more likely up to a certain point, but seeing even more ads after that does not necessarily increase the chance of buying.

# %% [markdown]
# ### 4.3 Ad Exposure at Peak Ad Hours Level

# %% [markdown]
# This section investigates how purchase rates vary by the hour of peak ad exposure (peak_ad_hours).
# Before examining purchase rates by peak hour, the distribution of users across peak hours is inspected in order to assess the reliability of the estimates.

# %%
# Check distribution of samples across peak hours

peak_hour_samples = ab_test_df.groupby(['peak_ad_hours']).agg({
    'customerID': 'count',
    'made_purchase': 'sum'
}).rename(columns={'customerID': 'total_customers', 'made_purchase': 'purchases'})

peak_hour_samples
# Out:
#                total_customers  purchases
# peak_ad_hours
# 0                          380         25
# 1                          351         18
# 2                          366         17
# 3                          342         14
# 4                          379         12
# 5                          332         27
# 6                          341         15
# 7                          352         27
# 8                          358         19
# 9                          390         18
# 10                         354         11
# 11                         368         16
# 12                         343         20
# 13                         344         13
# 15                        1635         80
# 16                        1690         88
# 17                        1605         83
# 18                        1749        109
# 19                        1649         86
# 20                        1653         95
# 21                        1641         96
# ...

# %%
# Bar plot: amount of users per peak ad hour

plt.figure(figsize=(10,6))
sns.barplot(data=peak_hour_samples, x='peak_ad_hours', y='total_customers')
plt.title('Amount of Users per Peak Ad Hour')
plt.xlabel('Peak Ad Hours')
plt.ylabel('Total Customers')
plt.show()

# %% [markdown]
# This table reveals a major sample size imbalance: early hours (0–14) each contain only about 350 customers, while late afternoon/evening hours (15–23) have around 1,600–1,750 customers. This might be due to user activity patterns as people are more active online later during the day and at night.

# %%
# Group ab_test_df by 'peak_ad_hours' and purchase rate in percent to see how the hour of 
# peak ad exposure affects purchase likelihood

peak_hour_purchase_rate_df = ab_test_df.groupby(['peak_ad_hours']).agg({'made_purchase': 'mean'}) * 100
peak_hour_purchase_rate_df
# Rename 'made_purchase' to 'purchase_rate_pct'
peak_hour_purchase_rate_df.rename(columns = {'made_purchase': 'purchase_rate_pct'}, inplace = True)
peak_hour_purchase_rate_df
# Out:
#                purchase_rate_pct
# peak_ad_hours
# 0                       6.578947
# 1                       5.128205
# 2                       4.644809
# 3                       4.093567
# 4                       3.166227
# 5                       8.132530
# 6                       4.398827
# 7                       7.670455
# 8                       5.307263
# 9                       4.615385
# 10                      3.107345
# 11                      4.347826
# 12                      5.830904
# 13                      3.779070
# 15                      4.892966
# 16                      5.207101
# 17                      5.171340
# 18                      6.232133
# 19                      5.215282
# 20                      5.747126
# 21                      5.850091
# 22                      4.836759
# 23                      5.278422

# %%
# Bar plot: purchase rates per peak ad hour

plt.figure(figsize=(10,6))
sns.lineplot(data=peak_hour_purchase_rate_df, x='peak_ad_hours', y='purchase_rate_pct')
plt.title('Purchase Rates per Peak Ad Hour')
plt.xlabel('Peak Ad Hours')
plt.ylabel('Purchase Rates (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# Because the early hours have such small samples, their purchase rates fluctuate heavily (3–8%) and are likely dominated by noise. In contrast, the larger samples in the late hours produce much more stable purchase rates of around 5–6%.
#
# As a result, purchase rates across hours are not directly comparable. Patterns observed in early hours should be interpreted with caution, as they may not reflect true customer behavior, whereas patterns in the late hours are more reliable.

# %% [markdown]
# ### 4.4 Purchase Rates by Exposure Level: Ads vs. PSA

# %%
# Compare how exposure impacts purchase behavior for ads versus PSAs in percent

exposure_by_group_df = ab_test_df.groupby(['test_group', 'ad_count']).agg({'made_purchase': 'mean'}) * 100
exposure_by_group_df

# Rename 'made_purchase' to 'purchase_rate_pct'
exposure_by_group_df.rename(columns={'made_purchase': 'purchase_rate_pct'}, inplace=True)
exposure_by_group_df

# Convert exposure_by_group_df to wide format for increased readability
exposure_by_group_df_pivot = pd.pivot_table(exposure_by_group_df, 
                                           index = 'ad_count', 
                                            columns = 'test_group', 
                                            values = 'purchase_rate_pct')
exposure_by_group_df_pivot
# Out:
# test_group        ad       psa
# ad_count
# 1           5.657238  3.341902
# 2           7.792208  3.341902
# 3           6.902087  3.571429
# 4           5.324459  2.307692
# 5           6.256062  2.939015
# 6           6.414585  3.285421
# 7           8.202324  3.280318
# 8           6.867779  3.163950
# 9           6.408629  3.088803
# 10          6.385870  3.929679

# %% [markdown]
# The table shows the purchase rates in percent by ad exposure for both the Ad and PSA groups.  The results indicate that ad exposure does seem to increase the likelihood of a purchase, as the purchase rates of the ad group are consistently higher compared to the PSA group.
# In the Ad group, purchase rates tend to climb up with moderate exposure to ads. They hit a peak near seven ads at about 8.20 percent, and slightly decline afterwards. The PSA group stays pretty steady on the other hand. Purchase rates hover around 3 to 4 percent no matter the exposure level. This suggests PSAs do not really affect buying behavior much.

# %%
# Create a line chart visualizing the purchase behaviour by exposure to ads vs. PSAs

plt.figure(figsize=(8,5))
sns.lineplot(data=exposure_by_group_df, x='ad_count', y='purchase_rate_pct', hue='test_group', marker='o')
plt.title('Purchase Rate by Ad Exposure for Ad vs PSA Groups')
plt.xlabel('Number of Ads Seen')
plt.ylabel('Purchase Rate (Percent)')
plt.grid(True)
plt.show()

# %% [markdown]
# This line chart visualizes the same information as the pivot table above.
# It clearly shows that the Ad group consistently has higher purchase rates than the PSA group across all levels of ad exposure.

# %% [markdown]
# ## 5. Conclusions and Outlook

# %% [markdown]
# This analysis examined the impact of advertising exposure on purchase behavior using data from an A/B test comparing advertisements (Ads) and public service announcements (PSAs).
#
# At the group level, users exposed to ads were significantly more likely to make a purchase than users exposed to PSAs. The purchase rate in the ad group was more than twice as high as in the PSA group, and a two-proportion z-test confirmed that this difference is highly statistically significant. This provides strong evidence that ads are more effective than PSAs in driving purchases.
#
# At a more granular level, increasing ad exposure was associated with a modest increase in purchase probability, but only up to a certain point. Purchase rates in the ad group peaked at moderate exposure levels (around seven ads) and declined slightly thereafter. In contrast, purchase rates in the PSA group remained relatively stable across all exposure levels, suggesting that repeated PSA exposure does not meaningfully influence purchasing behavior.
#
# Finally, an exploratory analysis of peak ad exposure hours showed substantial variation in purchase rates during early hours, which is largely driven by small sample sizes. In later hours, where sample sizes are much larger, purchase rates were more stable and clustered around similar values. As a result, hourly patterns should be interpreted cautiously, especially for underrepresented time periods.
#
# Overall, the results suggest that advertising itself has a clear positive effect on purchase likelihood compared to PSAs, but increasing exposure beyond moderate levels yields diminishing returns. This highlights the importance of optimizing ad exposure rather than simply increasing frequency.

# %% [markdown]
# Moreover, several limitations should be considered when interpreting these findings. First, the dataset does not include customer-level demographic or behavioral variables, which prevents segmentation analyses and makes it impossible to see whether ads work differently for different types of users. Second, the dataset originates from Kaggle, and details about whether the data is synthetic or derived from real-world experiments are not fully documented, which may affect external validity. Finally, the analysis lacks business context regarding expected or target purchase rates. While relative differences between groups are clear, it is difficult to assess whether observed purchase rates represent strong or weak performance from a commercial perspective.
#
# Future work could address these limitations by incorporating richer user data, validating findings on real-world datasets, and applying models that explicitly capture non-linear exposure effects. This would enable a deeper understanding of how advertising frequency and timing influence customer behavior in practice. In addition to that, statistical tests and modeling approaches to better assess the robustness of the observed patterns could be integrated, particularly for non-linear relationships between ad exposure and purchase behavior.
